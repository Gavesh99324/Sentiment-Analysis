# %%
# !pip install mlflow boto3 awscli
# Out:
# Requirement already satisfied: mlflow in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (2.17.0)
# Requirement already satisfied: boto3 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (1.35.36)
# Collecting awscli
#   Downloading awscli-1.43.15-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: mlflow-skinny==2.17.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow) (2.17.0)
# Requirement already satisfied: Flask<4 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow) (3.0.3)
# Requirement already satisfied: alembic!=1.10.0,<2 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow) (1.17.1)
# Requirement already satisfied: docker<8,>=4.0.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: graphene<4 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow) (3.4.3)
# Requirement already satisfied: markdown<4,>=3.3 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow) (3.10)
# Requirement already satisfied: matplotlib<4 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow) (3.9.2)
# Requirement already satisfied: numpy<3 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow) (2.1.2)
# Requirement already satisfied: pandas<3 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow) (2.2.3)
# Requirement already satisfied: pyarrow<18,>=4.0.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow) (17.0.0)
# Requirement already satisfied: scikit-learn<2 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow) (1.7.2)
# Requirement already satisfied: scipy<2 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow) (1.16.3)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow) (2.0.44)
# Requirement already satisfied: Jinja2<4,>=3.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow) (3.1.6)
# Requirement already satisfied: waitress<4 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow) (3.0.2)
# Requirement already satisfied: cachetools<6,>=5.0.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (8.3.0)
# Requirement already satisfied: cloudpickle<4 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (3.1.2)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (0.73.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (3.1.45)
# Requirement already satisfied: importlib-metadata!=4.7.0,<9,>=3.7.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (1.38.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (1.38.0)
# Requirement already satisfied: packaging<25 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (24.2)
# Requirement already satisfied: protobuf<6,>=3.12.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (5.29.5)
# Requirement already satisfied: pyyaml<7,>=5.1 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (6.0.3)
# Requirement already satisfied: requests<3,>=2.17.3 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (2.32.5)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from mlflow-skinny==2.17.0->mlflow) (0.5.3)
# Requirement already satisfied: Mako in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.10)
# Requirement already satisfied: typing-extensions>=4.12 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from alembic!=1.10.0,<2->mlflow) (4.15.0)
# Requirement already satisfied: colorama in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from click<9,>=7.0->mlflow-skinny==2.17.0->mlflow) (0.4.6)
# Requirement already satisfied: google-auth~=2.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (2.43.0)
# Requirement already satisfied: pywin32>=304 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from docker<8,>=4.0.0->mlflow) (311)
# Requirement already satisfied: urllib3>=1.26.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from docker<8,>=4.0.0->mlflow) (2.5.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from Flask<4->mlflow) (1.9.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.17.0->mlflow) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.17.0->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (4.7.2)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from graphene<4->mlflow) (3.2.7)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from graphene<4->mlflow) (2.9.0.post0)
# Requirement already satisfied: zipp>=3.20 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from importlib-metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.17.0->mlflow) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from Jinja2<4,>=3.0->mlflow) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from matplotlib<4->mlflow) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from matplotlib<4->mlflow) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from matplotlib<4->mlflow) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from matplotlib<4->mlflow) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from matplotlib<4->mlflow) (3.2.5)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.59b0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.17.0->mlflow) (0.59b0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from pandas<3->mlflow) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.0->mlflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.0->mlflow) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.17.0->mlflow) (2025.10.5)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.17.0->mlflow) (0.6.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from scikit-learn<2->mlflow) (3.6.0)
# Requirement already satisfied: greenlet>=1 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.2.4)
# Requirement already satisfied: botocore<1.36.0,>=1.35.36 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from boto3) (1.35.36)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from boto3) (1.0.1)
# Requirement already satisfied: s3transfer<0.11.0,>=0.10.0 in c:\users\user\anaconda3\envs\ytsa\lib\site-packages (from boto3) (0.10.4)
# INFO: pip is looking at multiple versions of awscli to determine which version is compatible with other requirements. This could take a while.
#   Downloading awscli-1.43.14-py3-none-any.whl.metadata (11 kB)
#   Using cached awscli-1.43.13-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.43.12-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.43.11-py3-none-any.whl.metadata (11 kB)
#   Using cached awscli-1.43.10-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.43.9-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.43.8-py3-none-any.whl.metadata (11 kB)
# INFO: pip is still looking at multiple versions of awscli to determine which version is compatible with other requirements. This could take a while.
#   Downloading awscli-1.43.7-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.43.6-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.43.5-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.43.4-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.43.3-py3-none-any.whl.metadata (11 kB)
# INFO: This is taking longer than usual. You might need to provide the dependency resolver with stricter constraints to reduce runtime. See https://pip.pypa.io/warnings/backtracking for guidance. If you want to abort this run, press Ctrl + C.
#   Downloading awscli-1.43.2-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.43.1-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.43.0-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.76-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.75-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.74-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.73-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.72-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.71-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.70-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.69-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.68-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.67-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.66-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.65-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.64-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.63-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.62-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.61-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.60-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.59-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.58-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.57-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.56-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.55-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.54-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.53-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.52-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.51-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.50-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.49-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.48-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.47-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.46-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.45-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.44-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.43-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.42-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.41-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.40-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.39-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.38-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.37-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.36-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.35-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.34-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.33-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.32-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.31-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.30-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.29-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.28-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.27-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.26-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.25-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.24-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.23-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.22-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.21-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.20-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.19-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.18-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.17-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.16-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.15-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.14-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.13-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.12-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.11-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.10-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.9-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.8-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.7-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.6-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.5-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.4-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.3-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.2-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.1-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.42.0-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.17-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.16-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.15-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.14-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.13-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.12-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.11-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.10-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.9-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.8-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.7-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.6-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.5-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.4-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.3-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.2-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.1-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.41.0-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.45-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.44-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.43-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.42-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.41-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.40-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.39-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.38-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.37-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.36-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.35-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.34-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.33-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.32-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.31-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.30-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.29-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.28-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.27-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.26-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.25-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.24-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.23-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.22-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.21-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.20-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.19-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.18-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.17-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.16-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.15-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.14-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.13-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.12-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.11-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.10-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.9-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.8-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.7-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.6-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.5-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.4-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.3-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.2-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.1-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.40.0-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.39.0-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.38-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.37-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.36-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.35-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.34-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.33-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.32-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.31-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.30-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.29-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.28-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.27-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.26-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.25-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.24-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.23-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.22-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.21-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.20-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.19-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.18-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.17-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.16-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.15-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.14-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.13-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.12-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.11-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.10-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.9-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.8-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.7-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.6-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.5-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.4-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.3-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.2-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.1-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.38.0-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.26-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.25-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.24-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.23-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.22-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.21-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.20-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.19-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.18-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.17-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.16-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.15-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.14-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.13-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.12-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.11-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.10-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.9-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.8-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.7-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.6-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.5-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.4-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.3-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.2-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.1-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.37.0-py3-none-any.whl.metadata (11 kB)
#   Downloading awscli-1.36.40-py3-none-any.whl.metadata (11 kB)
# Collecting botocore<1.36.0,>=1.35.36 (from boto3)
#   Using cached botocore-1.35.99-py3-none-any.whl.metadata (5.7 kB)
# Collecting docutils<0.17,>=0.10 (from awscli)
#   Downloading docutils-0.16-py2.py3-none-any.whl.metadata (2.7 kB)
# Downloading awscli-1.36.40-py3-none-any.whl (4.6 MB)
#    ---------------------------------------- 0.0/4.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/4.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/4.6 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.6 MB 1.5 MB/s eta 0:00:03
#    ------ --------------------------------- 0.8/4.6 MB 1.4 MB/s eta 0:00:03
#    ----------- ---------------------------- 1.3/4.6 MB 1.4 MB/s eta 0:00:03
#    ------------- -------------------------- 1.6/4.6 MB 1.4 MB/s eta 0:00:03
#    ------------------ --------------------- 2.1/4.6 MB 1.6 MB/s eta 0:00:02
#    ---------------------- ----------------- 2.6/4.6 MB 1.7 MB/s eta 0:00:02
#    ------------------------- -------------- 2.9/4.6 MB 1.7 MB/s eta 0:00:01
#    --------------------------- ------------ 3.1/4.6 MB 1.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 3.4/4.6 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.9/4.6 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  4.5/4.6 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 4.6/4.6 MB 1.7 MB/s  0:00:02
# Using cached botocore-1.35.99-py3-none-any.whl (13.3 MB)
# Downloading docutils-0.16-py2.py3-none-any.whl (548 kB)
#    ---------------------------------------- 0.0/548.2 kB ? eta -:--:--
#    ------------------- -------------------- 262.1/548.2 kB ? eta -:--:--
#    ---------------------------------------- 548.2/548.2 kB 2.3 MB/s  0:00:00
# Installing collected packages: docutils, botocore, awscli
#
#   Attempting uninstall: docutils
#
#     Found existing installation: docutils 0.19
#
#     Uninstalling docutils-0.19:
#
#       Successfully uninstalled docutils-0.19
#
#    ---------------------------------------- 0/3 [docutils]
#    ---------------------------------------- 0/3 [docutils]
#    ---------------------------------------- 0/3 [docutils]
#    ---------------------------------------- 0/3 [docutils]
#   Attempting uninstall: botocore
#    ---------------------------------------- 0/3 [docutils]
#     Found existing installation: botocore 1.35.36
#    ---------------------------------------- 0/3 [docutils]
#    ------------- -------------------------- 1/3 [botocore]
#    ------------- -------------------------- 1/3 [botocore]
#     Uninstalling botocore-1.35.36:
#    ------------- -------------------------- 1/3 [botocore]
#    ------------- -------------------------- 1/3 [botocore]
#       Successfully uninstalled botocore-1.35.36
#    ------------- -------------------------- 1/3 [botocore]
#    ------------- -------------------------- 1/3 [botocore]
#    ------------- -------------------------- 1/3 [botocore]
#    ------------- -------------------------- 1/3 [botocore]
#    ------------- -------------------------- 1/3 [botocore]
#    ------------- -------------------------- 1/3 [botocore]
#    ------------- -------------------------- 1/3 [botocore]
#    ------------- -------------------------- 1/3 [botocore]
#    ------------- -------------------------- 1/3 [botocore]
#    ------------- -------------------------- 1/3 [botocore]
#    ------------- -------------------------- 1/3 [botocore]
#    ------------- -------------------------- 1/3 [botocore]
#    ------------- -------------------------- 1/3 [botocore]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    -------------------------- ------------- 2/3 [awscli]
#    ---------------------------------------- 3/3 [awscli]
#
# Successfully installed awscli-1.36.40 botocore-1.35.99 docutils-0.16

# %%
import mlflow
mlflow.set_tracking_uri("http://ec2-98-89-32-32.compute-1.amazonaws.com:5000/")

# %%
mlflow.set_experiment("Exp 2 - BoW vs TfIdf")
# Out:
# <Experiment: artifact_location='s3://mlflow-s3-bucket-25/118435417726069699', creation_time=1765642375192, experiment_id='118435417726069699', last_update_time=1765642375192, lifecycle_stage='active', name='Exp 2 - BoW vs TfIdf', tags={}>

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import mlflow.sklearn
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os

# %%
df = pd.read_csv('reddit_preprocessing.csv').dropna(subset=['clean_comment'])
df.shape
# Out:
# (36662, 2)

# %%
# Run experiment
def run_experiment(vectorizer_type, ngram_range, vectorizer_max_features, vectorizer_name):
    # Vectorization
    if vectorizer_type == "BoW":
        vectorizer = CountVectorizer(
            ngram_range=ngram_range, max_features=vectorizer_max_features)
    else:
        vectorizer = TfidfVectorizer(
            ngram_range=ngram_range, max_features=vectorizer_max_features)

    X_train, X_test, y_train, y_test = train_test_split(
        df['clean_comment'], df['category'], test_size=0.2, random_state=42, stratify=df['category'])

    X_train = vectorizer.fit_transform(X_train)
    X_test = vectorizer.transform(X_test)

    # Define and train a Random Forest model
    with mlflow.start_run() as run:
        # Set tags for the experiment and run
        mlflow.set_tag("mlflow.runName",
                       f"{vectorizer_name}_{ngram_range}_RandomForest")
        mlflow.set_tag("experiment_type", "feature_engineering")
        mlflow.set_tag("model_type", "RandomForestClassifier")

        # Add a description
        mlflow.set_tag(
            "description", f"RandomForest with {vectorizer_name}, ngram_range={ngram_range}, max_features={vectorizer_max_features}")

        # Log vectorizer parameters
        mlflow.log_param("vectorizer_type", vectorizer_type)
        mlflow.log_param("ngram_range", ngram_range)
        mlflow.log_param("vectorizer_max_features", vectorizer_max_features)

        # Log Random Forest parameters
        n_estimators = 200
        max_depth = 15

        mlflow.log_param("n_estimators", n_estimators)
        mlflow.log_param("max_depth", max_depth)

        # Initialize and train the model
        model = RandomForestClassifier(
            n_estimators=n_estimators, max_depth=max_depth, random_state=42)
        model.fit(X_train, y_train)

        # Make predictions and log metrics
        y_pred = model.predict(X_test)

        # Log accuracy
        accuracy = accuracy_score(y_test, y_pred)
        mlflow.log_metric("accuracy", accuracy)

        # Log classification report
        classification_rep = classification_report(
            y_test, y_pred, output_dict=True)
        for label, metrics in classification_rep.items():
            if isinstance(metrics, dict):
                for metric, value in metrics.items():
                    mlflow.log_metric(f"{label}_{metric}", value)

        # Log confusion matrix
        conf_matrix = confusion_matrix(y_test, y_pred)
        plt.figure(figsize=(8, 6))
        sns.heatmap(conf_matrix, annot=True, fmt="d", cmap="Blues")
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title(f"Confusion Matrix: {vectorizer_name}, {ngram_range}")
        plt.savefig("confusion_matrix.png")
        mlflow.log_artifact("confusion_matrix.png")
        plt.close()

        # Log the model
        mlflow.sklearn.log_model(
            model, f"random_forest_model_{vectorizer_name}_{ngram_range}")


# Run experiments for BoW and TF-IDF with different n-grams
ngram_ranges = [(1, 1), (1, 2), (1, 3)]  # unigrams, bigrams, trigrams
max_features = 5000  # Example max feature size

for ngram_range in ngram_ranges:
    # BoW Experiments
    run_experiment("BoW", ngram_range, max_features, vectorizer_name="BoW")

    # TF-IDF Experiments
    run_experiment("TF-IDF", ngram_range, max_features,
                   vectorizer_name="TF-IDF")
# Out:
# 2025/12/13 22:37:10 INFO mlflow.tracking._tracking_service.client: 🏃 View run BoW_(1, 1)_RandomForest at: http://ec2-98-89-32-32.compute-1.amazonaws.com:5000/#/experiments/118435417726069699/runs/a2270278899d494f9dc995fac269f177.
# 2025/12/13 22:37:10 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: http://ec2-98-89-32-32.compute-1.amazonaws.com:5000/#/experiments/118435417726069699.
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Users\USER\anaconda3\envs\ytsa\Lib\site-packages\boto3\s3\transfer.py:372, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     371 try:
# --> 372     future.result()
#     373 # If a client error was raised, add the backwards compatibility layer
#     374 # that raises a S3UploadFailedError. These specific errors were only
#     375 # ever thrown for upload_parts but now can be thrown for any related
#     376 # client error.
#
# File c:\Users\USER\anaconda3\envs\ytsa\Lib\site-packages\s3transfer\futures.py:103, in TransferFuture.result(self)
#      99 try:
#     100     # Usually the result() method blocks until the transfer is done,
#     101     # however if a KeyboardInterrupt is raised we want want to exit
#     102     # out of this and propagate the exception.
# --> 103     return self._coordinator.result()
#     104 except KeyboardInterrupt as e:
#
# File c:\Users\USER\anaconda3\envs\ytsa\Lib\site-packages\s3transfer\futures.py:264, in TransferCoordinator.result(self)
#     263 if self._exception:
# --> 264     raise self._exception
#     265 return self._result
#
# File c:\Users\USER\anaconda3\envs\ytsa\Lib\site-packages\s3transfer\tasks.py:135, in Task.__call__(self)
#     134     if not self._transfer_coordinator.done():
# --> 135         return self._execute_main(kwargs)
#     136 except Exception as e:
#
# File c:\Users\USER\anaconda3\envs\ytsa\Lib\site-packages\s3transfer\tasks.py:158, in Task._execute_main(self, kwargs)
#     156 logger.debug(f"Executing task {self} with kwargs {kwargs_to_display}")
# --> 158 return_value = self._main(**kwargs)
#     159 # If the task is the final task, then set the TransferFuture's
#     160 # value to the return value from main().
#
# File c:\Users\USER\anaconda3\envs\ytsa\Lib\site-packages\s3transfer\upload.py:762, in PutObjectTask._main(self, client, fileobj, bucket, key, extra_args)
#     761 with fileobj as body:
# --> 762     client.put_object(Bucket=bucket, Key=key, Body=body, **extra_args)
#
# File c:\Users\USER\anaconda3\envs\ytsa\Lib\site-packages\botocore\client.py:569, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     568 # The "self" in this scope is referring to the BaseClient.
# --> 569 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\USER\anaconda3\envs\ytsa\Lib\site-packages\botocore\client.py:1023, in BaseClient._make_api_call(self, operation_name, api_params)
#    1022     error_class = self.exceptions.from_code(error_code)
# -> 1023     raise error_class(parsed_response, operation_name)
#    1024 else:
#
# ClientError: An error occurred (SignatureDoesNotMatch) when calling the PutObject operation: The request signature we calculated does not match the signature you provided. Check your key and signing method.
#
# During handling of the above exception, another exception occurred:
#
# S3UploadFailedError                       Traceback (most recent call last)
# Cell In[5], line 83
#      79 max_features = 5000  # Example max feature size
#      81 for ngram_range in ngram_ranges:
#      82     # BoW Experiments
# ---> 83     run_experiment("BoW", ngram_range, max_features, vectorizer_name="BoW")
#      85     # TF-IDF Experiments
#      86     run_experiment("TF-IDF", ngram_range, max_features,
#      87                    vectorizer_name="TF-IDF")
#
# Cell In[5], line 69, in run_experiment(vectorizer_type, ngram_range, vectorizer_max_features, vectorizer_name)
#      67 plt.title(f"Confusion Matrix: {vectorizer_name}, {ngram_range}")
#      68 plt.savefig("confusion_matrix.png")
# ---> 69 mlflow.log_artifact("confusion_matrix.png")
#      70 plt.close()
#      72 # Log the model
#
# File c:\Users\USER\anaconda3\envs\ytsa\Lib\site-packages\mlflow\tracking\fluent.py:1130, in log_artifact(local_path, artifact_path, run_id)
#    1100 """
#    1101 Log a local file or directory as an artifact of the currently active run. If no run is
#    1102 active, this method will create a new active run.
#    (...)   1127             mlflow.log_artifact(path)
#    1128 """
#    1129 run_id = run_id or _get_or_start_run().info.run_id
# -> 1130 MlflowClient().log_artifact(run_id, local_path, artifact_path)
#
# File c:\Users\USER\anaconda3\envs\ytsa\Lib\site-packages\mlflow\tracking\client.py:1928, in MlflowClient.log_artifact(self, run_id, local_path, artifact_path)
#    1924 if run_id.startswith(TRACE_REQUEST_ID_PREFIX):
#    1925     raise MlflowException(
#    1926         f"Invalid run id: {run_id}. `log_artifact` run id must map to a valid run."
#    1927     )
# -> 1928 self._tracking_client.log_artifact(run_id, local_path, artifact_path)
#
# File c:\Users\USER\anaconda3\envs\ytsa\Lib\site-packages\mlflow\tracking\_tracking_service\client.py:841, in TrackingServiceClient.log_artifact(self, run_id, local_path, artifact_path)
#     839     artifact_repo.log_artifacts(local_path, path_name)
#     840 else:
# --> 841     artifact_repo.log_artifact(local_path, artifact_path)
#
# File c:\Users\USER\anaconda3\envs\ytsa\Lib\site-packages\mlflow\store\artifact\s3_artifact_repo.py:176, in S3ArtifactRepository.log_artifact(self, local_file, artifact_path)
#     174     dest_path = posixpath.join(dest_path, artifact_path)
#     175 dest_path = posixpath.join(dest_path, os.path.basename(local_file))
# --> 176 self._upload_file(
#     177     s3_client=self._get_s3_client(), local_file=local_file, bucket=bucket, key=dest_path
#     178 )
#
# File c:\Users\USER\anaconda3\envs\ytsa\Lib\site-packages\mlflow\store\artifact\s3_artifact_repo.py:169, in S3ArtifactRepository._upload_file(self, s3_client, local_file, bucket, key)
#     167 if environ_extra_args is not None:
#     168     extra_args.update(environ_extra_args)
# --> 169 s3_client.upload_file(Filename=local_file, Bucket=bucket, Key=key, ExtraArgs=extra_args)
#
# File c:\Users\USER\anaconda3\envs\ytsa\Lib\site-packages\boto3\s3\inject.py:145, in upload_file(self, Filename, Bucket, Key, ExtraArgs, Callback, Config)
#     110 """Upload a file to an S3 object.
#     111
#     112 Usage::
#    (...)    142     transfer.
#     143 """
#     144 with S3Transfer(self, Config) as transfer:
# --> 145     return transfer.upload_file(
#     146         filename=Filename,
#     147         bucket=Bucket,
#     148         key=Key,
#     149         extra_args=ExtraArgs,
#     150         callback=Callback,
#     151     )
#
# File c:\Users\USER\anaconda3\envs\ytsa\Lib\site-packages\boto3\s3\transfer.py:378, in S3Transfer.upload_file(self, filename, bucket, key, callback, extra_args)
#     373 # If a client error was raised, add the backwards compatibility layer
#     374 # that raises a S3UploadFailedError. These specific errors were only
#     375 # ever thrown for upload_parts but now can be thrown for any related
#     376 # client error.
#     377 except ClientError as e:
# --> 378     raise S3UploadFailedError(
#     379         "Failed to upload {} to {}: {}".format(
#     380             filename, '/'.join([bucket, key]), e
#     381         )
#     382     )
#
# S3UploadFailedError: Failed to upload confusion_matrix.png to mlflow-s3-bucket-25/118435417726069699/a2270278899d494f9dc995fac269f177/artifacts/confusion_matrix.png: An error occurred (SignatureDoesNotMatch) when calling the PutObject operation: The request signature we calculated does not match the signature you provided. Check your key and signing method.
